# %%
import dhlab.nbtext as nb
from collections import Counter
from Giella_tekno_api import sami_word

# %%
def word_info(x, **kwargs):
    try:
        return sami_word(x, **kwargs)['analyses']
    except:
        return dict()

# %%
def unigram_agg(words, compare= None, **kwargs):
    import pandas as pd
    
    unis = dict()
    for w in words:
        unis[w] = nb.unigram(w, **kwargs)
        unis[w].columns = [w]
    agg = pd.concat([unis[w] for w in unis], sort=False, axis=1).sum(axis=1)
    if compare != None:
        comp = nb.unigram(compare, **kwargs)
        res = nb.frame(agg/comp[0])
    else:
        res = nb.frame(agg)
    return res

# %%
unigram_agg('spise spiser spiste'.split(), lang='sme', period=(1990, 2000))
# Out:
#          0
# 1993  26.0
# 1994   1.0
# 1995   2.0
# 1993   1.0
# 1995   5.0
# 1998   1.0
# 2000   2.0
# 1995   1.0

# %%
word_info('leat', pos='V')
# Out:
# {'V+Inf': ['leat', 'leahkit'],
#  'V+Ind+Prs+Sg1': ['lean'],
#  'V+Ind+Prs+Sg2': ['leat'],
#  'V+Ind+Prs+Sg3': ['lea'],
#  'V+Ind+Prs+Du1': ['letne', 'ledne'],
#  'V+Ind+Prs+Du2': ['leahppi'],
#  'V+Ind+Prs+Du3': ['leaba'],
#  'V+Ind+Prs+Pl1': ['leat'],
#  'V+Ind+Prs+Pl2': ['lehpet'],
#  'V+Ind+Prs+Pl3': ['leat'],
#  'V+Ind+Prs+ConNeg': ['leat'],
#  'V+Ind+Prt+Sg1': ['ledjen'],
#  'V+Ind+Prt+Sg2': ['ledjet'],
#  'V+Ind+Prt+Sg3': ['lei', 'leai'],
#  'V+Ind+Prt+Du1': ['leimme'],
#  'V+Ind+Prt+Du2': ['leidde'],
#  'V+Ind+Prt+Du3': ['leaigga', 'leigga'],
#  'V+Ind+Prt+Pl1': ['leimmet'],
#  'V+Ind+Prt+Pl2': ['leiddet'],
#  'V+Ind+Prt+Pl3': ['ledje'],
#  'V+Ind+Prt+ConNeg': ['lean'],
#  'V+Cond+Prs+Sg1': ['livččen'],
#  'V+Cond+Prs+Sg2': ['livččet'],
#  'V+Cond+Prs+Sg3': ['livččii'],
#  'V+Cond+Prs+Du1': ['livččiime'],
#  'V+Cond+Prs+Du2': ['livččiide'],
#  'V+Cond+Prs+Du3': ['livččiiga'],
#  'V+Cond+Prs+Pl1': ['livččiimet'],
#  'V+Cond+Prs+Pl2': ['livččiidet'],
#  'V+Cond+Prs+Pl3': ['livčče'],
#  'V+Cond+Prs+ConNeg': ['livčče'],
#  'V+Imprt+Sg1': ['lehkon'],
#  'V+Imprt+Sg2': ['leage'],
#  'V+Imprt+Sg3': ['lehkos'],
#  'V+Imprt+Du1': ['leahkku', 'leadnu'],
#  'V+Imprt+Du2': ['leahkki'],
#  'V+Imprt+Du3': ['lehkoska'],
#  'V+Imprt+Pl1': ['lehkot', 'leatnot'],
#  'V+Imprt+Pl2': ['lehket'],
#  'V+Imprt+Pl3': ['lehkoset'],
#  'V+Imprt+ConNeg': ['leage'],
#  'V+Pot+Prs+Sg1': ['leaččan'],
#  'V+Pot+Prs+Sg2': ['leaččat'],
#  'V+Pot+Prs+Sg3': ['leš', 'leaš', 'leažžá'],
#  'V+Pot+Prs+Du1': ['ležže'],
#  'V+Pot+Prs+Du2': ['leažžabeahtti'],
#  'V+Pot+Prs+Du3': ['leažžaba'],
#  'V+Pot+Prs+Pl1': ['leažžat'],
#  'V+Pot+Prs+Pl2': ['leažžabehtet'],
#  'V+Pot+Prs+Pl3': ['ležžet'],
#  'V+Pot+Prs+ConNeg': ['leš', 'leaš', 'leačča'],
#  'V+Pot+Prt+Sg1': ['ležžen'],
#  'V+Pot+Prt+Sg2': ['ležžet'],
#  'V+Pot+Prt+Sg3': ['leaččai'],
#  'V+Pot+Prt+Du1': ['leaččaime'],
#  'V+Pot+Prt+Du2': ['leaččaide'],
#  'V+Pot+Prt+Du3': ['leaččaiga'],
#  'V+Pot+Prt+Pl1': ['leaččaimet'],
#  'V+Pot+Prt+Pl2': ['leaččaidet'],
#  'V+Pot+Prt+Pl3': ['ležže'],
#  'V+PrfPrc': ['leamaš', 'leamašan'],
#  'V+PrsPrc': ['leahkki'],
#  'V+Actio+Loc': ['leames'],
#  'V+Actio+Ess': ['leamen', 'leame', 'leahkime']}

# %%
urn = nb.book_urn(lang='sme', limit=3000)

len(urn)
# Out:
# 1032

# %%
step =300
sami_count = Counter()
for i in range(0, len(urn), step):
    print(i)
    sami_count.update(nb.aggregate_urns(urn[i:i+step]))
# Out:
# 0
# 300
# 600
# 900

# %%
tot_sami = nb.frame_sort(nb.frame(sami_count, 'counts'))

# %%
ref_urn = nb.refine_book_urn(words='oktasaš', lang='sme',urns=urn,limit=1000 )
len(ref_urn)
# Out:
# 892

# %%
forms = word_info("oahpaheamis")

# %%
fisk_v = word_info('bivdit')

# %%
fisk_n = word_info('bivdit', pos='N')

# %%
def invert(definition):
    return {k:[v for v in definition.keys() if k in definition[v]] for values in definition.values() for k in values}

# %%
invert(fisk_n)['bivdi']
# Out:
# ['N+Sg+Nom',
#  'N+Sg+Gen',
#  'N+Sg+Acc',
#  'N+NomAg+Sg+Nom',
#  'N+NomAg+Sg+Gen',
#  'N+NomAg+Sg+Acc']

# %%
fisk_v_df = nb.frame(invert(fisk_v))

# %%
def distribution(forms, tot_sami):
    words = {z for x in forms for z in x}

    words_pluss = [w for w in words if w in tot_sami.index]
    words_minus = [w for w in words if not w in tot_sami.index]

    print('med belegg:',len(words_pluss), 'uten belegg:', len(words_minus))

    return tot_sami.loc[words_pluss].sort_values(by='counts', ascending=False)

# %%
dist = distribution(fisk_v.values(), tot_sami)
# Out:
# med belegg: 35 uten belegg: 55

# %%
dist
# Out:
#                counts
# bivdit           1786
# bivde             637
# bivddii           352
# bivdu             340
# bivdet            336
# bivdi             215
# bivdimin          146
# bivdde            121
# bivdán             92
# bivdin             83
# bivdá              56
# bivdime            47
# bivdimis           40
# bivden             38
# bivddiiga          21
# bivddiimet         19
# bivdos             16
# bivdon             16
# bivddán            13
# bivdibehtet        10
# bivdiba            10
# bivdimiin           7
# bivddiime           6
# bivddášii           5
# bivdot              5
# bivddiide           4
# bivddát             3
# bivdimen            3
# bivdibeahtti        2
# bivddiidet          1
# bivddehaga          1
# bivddášin           1
# bivddášeimme        1
# bivddášedje         1
# bivddekeahttá       1

# %%
dist.head(10).index
# Out:
# Index(['bivdit', 'bivde', 'bivddii', 'bivdu', 'bivdet', 'bivdi', 'bivdimin',
#        'bivdde', 'bivdán', 'bivdin'],
#       dtype='object')

# %%
fisk_v_df.loc[[x for x in dist.head(10).index if x in fisk_v_df.index]].fillna('')
# Out:
#                          0              1               2
# bivdit               V+Inf  V+Ind+Prs+Pl1     V+Imprt+Pl2
# bivde        V+Ind+Prs+Du1  V+Ind+Prt+Pl3
# bivddii      V+Ind+Prt+Sg3
# bivdu          V+Imprt+Du1
# bivdet       V+Ind+Prs+Pl3  V+Ind+Prt+Sg2     V+Imprt+Pl2
# bivdi          V+Imprt+Du2       V+PrsPrc
# bivdimin       V+Actio+Ess
# bivdde    V+Ind+Prs+ConNeg    V+Imprt+Sg2  V+Imprt+ConNeg
# bivdán    V+Ind+Prt+ConNeg       V+PrfPrc
# bivdin         V+Actio+Nom    V+Actio+Gen

# %%
form_dist = lambda df, dist: df.loc[[x for x in dist.head(10).index if x in df.index]].fillna('')

# %%
sami_word("oahpaheamis", pos='N')
# Out:
# {'analyses': {'N+Sg+Nom': ['oahpaheapmi'],
#   'N+Sg+Gen': ['oahpaheame', 'oahpaheami'],
#   'N+Sg+Gen+Allegro': ['oahpaheame'],
#   'N+Sg+Acc': ['oahpaheami'],
#   'N+Sg+Ill': ['oahpaheapmái'],
#   'N+Sg+Loc': ['oahpaheames', 'oahpaheamis'],
#   'N+Sg+Com': ['oahpahemiin'],
#   'N+Pl+Nom': ['oahpaheamit'],
#   'N+Pl+Gen': ['oahpahemiid'],
#   'N+Pl+Acc': ['oahpahemiid'],
#   'N+Pl+Ill': ['oahpahemiide'],
#   'N+Pl+Loc': ['oahpahemiin'],
#   'N+Pl+Com': ['oahpahemiiguin'],
#   'N+Ess': ['oahpaheamen', 'oahpaheame', 'oahpaheapmin'],
#   'N+Sg+Nom+PxSg1': ['oahpaheapmán'],
#   'N+Sg+Nom+PxSg2': ['oahpaheapmát'],
#   'N+Sg+Nom+PxSg3': ['oahpaheapmis'],
#   'N+Sg+Nom+PxDu1': ['oahpaheapmáme'],
#   'N+Sg+Nom+PxDu2': ['oahpaheapmáde'],
#   'N+Sg+Nom+PxDu3': ['oahpaheapmiska'],
#   'N+Sg+Nom+PxPl1': ['oahpaheapmámet'],
#   'N+Sg+Nom+PxPl2': ['oahpaheapmádet'],
#   'N+Sg+Nom+PxPl3': ['oahpaheapmiset'],
#   'N+Sg+Gen+PxSg1': ['oahpaheapmán'],
#   'N+Sg+Gen+PxSg2': ['oahpaheamát'],
#   'N+Sg+Gen+PxSg3': ['oahpaheamis'],
#   'N+Sg+Gen+PxDu1': ['oahpaheapmáme'],
#   'N+Sg+Gen+PxDu2': ['oahpaheamáde'],
#   'N+Sg+Gen+PxDu3': ['oahpaheamiska'],
#   'N+Sg+Gen+PxPl1': ['oahpaheapmámet'],
#   'N+Sg+Gen+PxPl2': ['oahpaheamádet'],
#   'N+Sg+Gen+PxPl3': ['oahpaheamiset'],
#   'N+Sg+Acc+PxSg1': ['oahpaheapmán'],
#   'N+Sg+Acc+PxSg2': ['oahpaheamát'],
#   'N+Sg+Acc+PxSg3': ['oahpaheamis'],
#   'N+Sg+Acc+PxDu1': ['oahpaheapmáme'],
#   'N+Sg+Acc+PxDu2': ['oahpaheamáde'],
#   'N+Sg+Acc+PxDu3': ['oahpaheamiska'],
#   'N+Sg+Acc+PxPl1': ['oahpaheapmámet'],
#   'N+Sg+Acc+PxPl2': ['oahpaheamádet'],
#   'N+Sg+Acc+PxPl3': ['oahpaheamiset'],
#   'N+Sg+Ill+PxSg1': ['oahpaheapmásan'],
#   'N+Sg+Ill+PxSg2': ['oahpaheapmásat'],
#   'N+Sg+Ill+PxSg3': ['oahpaheapmásis'],
#   'N+Sg+Ill+PxDu1': ['oahpaheapmáseame'],
#   'N+Sg+Ill+PxDu2': ['oahpaheapmáseatte'],
#   'N+Sg+Ill+PxDu3': ['oahpaheapmáseaskka'],
#   'N+Sg+Ill+PxPl1': ['oahpaheapmáseamet'],
#   'N+Sg+Ill+PxPl2': ['oahpaheapmáseattet'],
#   'N+Sg+Ill+PxPl3': ['oahpaheapmáseaset'],
#   'N+Sg+Loc+PxSg1': ['oahpaheamistan'],
#   'N+Sg+Loc+PxSg2': ['oahpaheamistat'],
#   'N+Sg+Loc+PxSg3': ['oahpaheamistis'],
#   'N+Sg+Loc+PxDu1': ['oahpaheamisteame'],
#   'N+Sg+Loc+PxDu2': ['oahpaheamisteatte'],
#   'N+Sg+Loc+PxDu3': ['oahpaheamisteaskka'],
#   'N+Sg+Loc+PxPl1': ['oahpaheamisteamet'],
#   'N+Sg+Loc+PxPl2': ['oahpaheamisteattet'],
#   'N+Sg+Loc+PxPl3': ['oahpaheamisteaset'],
#   'N+Sg+Com+PxSg1': ['oahpahemiinan'],
#   'N+Sg+Com+PxSg2': ['oahpahemiinat'],
#   'N+Sg+Com+PxSg3': ['oahpahemiinis'],
#   'N+Sg+Com+PxDu1': ['oahpahemiineame'],
#   'N+Sg+Com+PxDu2': ['oahpahemiineatte'],
#   'N+Sg+Com+PxDu3': ['oahpahemiineaskka'],
#   'N+Sg+Com+PxPl1': ['oahpahemiineamet'],
#   'N+Sg+Com+PxPl2': ['oahpahemiineattet'],
#   'N+Sg+Com+PxPl3': ['oahpahemiineaset'],
#   'N+Pl+Nom+PxSg1': ['oahpahemiidan'],
#   'N+Pl+Nom+PxDu1': ['oahpahemiideame'],
#   'N+Pl+Nom+PxPl1': ['oahpahemiideamet'],
#   'N+Pl+Gen+PxSg1': ['oahpahemiidan'],
#   'N+Pl+Gen+PxSg2': ['oahpahemiidat'],
#   'N+Pl+Gen+PxSg3': ['oahpahemiidis'],
#   'N+Pl+Gen+PxDu1': ['oahpahemiideame'],
#   'N+Pl+Gen+PxDu2': ['oahpahemiideatte'],
#   'N+Pl+Gen+PxDu3': ['oahpahemiideaskka'],
#   'N+Pl+Gen+PxPl1': ['oahpahemiideamet'],
#   'N+Pl+Gen+PxPl2': ['oahpahemiideattet'],
#   'N+Pl+Gen+PxPl3': ['oahpahemiideaset'],
#   'N+Pl+Acc+PxSg1': ['oahpahemiidan'],
#   'N+Pl+Acc+PxSg2': ['oahpahemiidat'],
#   'N+Pl+Acc+PxSg3': ['oahpahemiidis'],
#   'N+Pl+Acc+PxDu1': ['oahpahemiideame'],
#   'N+Pl+Acc+PxDu2': ['oahpahemiideatte'],
#   'N+Pl+Acc+PxDu3': ['oahpahemiideaskka'],
#   'N+Pl+Acc+PxPl1': ['oahpahemiideamet'],
#   'N+Pl+Acc+PxPl2': ['oahpahemiideattet'],
#   'N+Pl+Acc+PxPl3': ['oahpahemiideaset'],
#   'N+Pl+Ill+PxSg1': ['oahpahemiidasan'],
#   'N+Pl+Ill+PxSg2': ['oahpahemiidasat'],
#   'N+Pl+Ill+PxSg3': ['oahpahemiidasas'],
#   'N+Pl+Ill+PxDu1': ['oahpahemiidasame'],
#   'N+Pl+Ill+PxDu2': ['oahpahemiidasade'],
#   'N+Pl+Ill+PxDu3': ['oahpahemiidasaska'],
#   'N+Pl+Ill+PxPl1': ['oahpahemiidasamet'],
#   'N+Pl+Ill+PxPl2': ['oahpahemiidasadet'],
#   'N+Pl+Ill+PxPl3': ['oahpahemiidasaset'],
#   'N+Pl+Loc+PxSg1': ['oahpahemiinan'],
#   'N+Pl+Loc+PxSg2': ['oahpahemiinat'],
#   'N+Pl+Loc+PxSg3': ['oahpahemiinis'],
#   'N+Pl+Loc+PxDu1': ['oahpahemiineame'],
#   'N+Pl+Loc+PxDu2': ['oahpahemiineatte'],
#   'N+Pl+Loc+PxDu3': ['oahpahemiineaskka'],
#   'N+Pl+Loc+PxPl1': ['oahpahemiineamet'],
#   'N+Pl+Loc+PxPl2': ['oahpahemiineattet'],
#   'N+Pl+Loc+PxPl3': ['oahpahemiineaset'],
#   'N+Pl+Com+PxSg1': ['oahpahemiidanguin'],
#   'N+Pl+Com+PxSg2': ['oahpahemiidatguin'],
#   'N+Pl+Com+PxSg3': ['oahpahemiidisguin'],
#   'N+Pl+Com+PxDu1': ['oahpahemiideameguin'],
#   'N+Pl+Com+PxDu2': ['oahpahemiideatteguin'],
#   'N+Pl+Com+PxDu3': ['oahpahemiideaskkaguin'],
#   'N+Pl+Com+PxPl1': ['oahpahemiideametguin'],
#   'N+Pl+Com+PxPl2': ['oahpahemiideattetguin'],
#   'N+Pl+Com+PxPl3': ['oahpahemiideasetguin'],
#   'N+Ess+PxSg1': ['oahpaheapminan'],
#   'N+Ess+PxSg2': ['oahpaheapminat'],
#   'N+Ess+PxSg3': ['oahpaheapminis'],
#   'N+Ess+PxDu1': ['oahpaheapmineame'],
#   'N+Ess+PxDu2': ['oahpaheapmineatte'],
#   'N+Ess+PxDu3': ['oahpaheapmineaskka'],
#   'N+Ess+PxPl1': ['oahpaheapmineamet'],
#   'N+Ess+PxPl2': ['oahpaheapmineattet'],
#   'N+Ess+PxPl3': ['oahpaheapmineaset']}}

# %%
rein_n_df = nb.frame(word_info('boazu', pos='N'))

# %%
rein_n = word_info('boazu', pos='N')

# %%
snøscooter = word_info('muohtaskohter', pos='N')

# %%
distribution(snøscooter.values(), tot_sami)
# Out:
# med belegg: 7 uten belegg: 64
#                      counts
# muohtaskohtera           27
# muohtaskohteriin         18
# muohtaskohter            18
# muohtaskohteriid          8
# muohtaskohterat           6
# muohtaskohteris           1
# muohtaskohteriiguin       1

# %%
form_distribution = lambda x: form_dist(nb.frame(invert(x)), distribution(x.values(), tot_sami))

# %%
form_dist(nb.frame(invert(snøscooter)), distribution(snøscooter.values(), tot_sami))
# Out:
# med belegg: 7 uten belegg: 64
#                             0               1               2               3
# muohtaskohtera       N+Sg+Gen        N+Sg+Acc
# muohtaskohteriin     N+Sg+Com        N+Pl+Loc
# muohtaskohter        N+Sg+Nom
# muohtaskohteriid     N+Pl+Gen        N+Pl+Acc
# muohtaskohterat      N+Pl+Nom  N+Sg+Nom+PxSg2  N+Sg+Gen+PxSg2  N+Sg+Acc+PxSg2
# muohtaskohteris      N+Sg+Loc  N+Sg+Gen+PxSg3  N+Sg+Acc+PxSg3
# muohtaskohteriiguin  N+Pl+Com

# %%
rein_n_df
# Out:
#                                  0
# N+Sg+Nom                     boazu
# N+Sg+Gen                    bohcco
# N+Sg+Acc                    bohcco
# N+Sg+Ill                   bohccui
# N+Sg+Loc                   bohccos
# N+Sg+Com                  bohccuin
# N+Pl+Nom                   bohccot
# N+Pl+Gen                  bohccuid
# N+Pl+Acc                  bohccuid
# N+Pl+Ill                 bohccuide
# N+Pl+Loc                  bohccuin
# N+Pl+Com               bohccuiguin
# N+Ess                       boazun
# N+Sg+Nom+PxSg1             bohccon
# N+Sg+Nom+PxSg2             bohccot
# N+Sg+Nom+PxSg3             bohccos
# N+Sg+Nom+PxDu1            bohccome
# N+Sg+Nom+PxDu2            bohccode
# N+Sg+Nom+PxDu3           bohccoska
# N+Sg+Nom+PxPl1           bohccomet
# N+Sg+Nom+PxPl2           bohccodet
# N+Sg+Nom+PxPl3           bohccoset
# N+Sg+Gen+PxSg1             bohccon
# N+Sg+Gen+PxSg2             bohccot
# N+Sg+Gen+PxSg3             bohccos
# N+Sg+Gen+PxDu1            bohccome
# N+Sg+Gen+PxDu2            bohccode
# N+Sg+Gen+PxDu3           bohccoska
# N+Sg+Gen+PxPl1           bohccomet
# N+Sg+Gen+PxPl2           bohccodet
# ...                            ...
# N+Pl+Ill+PxPl1      bohccuidasamet
# N+Pl+Ill+PxPl2      bohccuidasadet
# N+Pl+Ill+PxPl3      bohccuidasaset
# N+Pl+Loc+PxSg1          bohccuinan
# N+Pl+Loc+PxSg2          bohccuinat
# N+Pl+Loc+PxSg3          bohccuinis
# N+Pl+Loc+PxDu1        bohccuineame
# N+Pl+Loc+PxDu2       bohccuineatte
# N+Pl+Loc+PxDu3      bohccuineaskka
# N+Pl+Loc+PxPl1       bohccuineamet
# N+Pl+Loc+PxPl2      bohccuineattet
# N+Pl+Loc+PxPl3       bohccuineaset
# N+Pl+Com+PxSg1      bohccuidanguin
# N+Pl+Com+PxSg2      bohccuidatguin
# N+Pl+Com+PxSg3      bohccuidisguin
# N+Pl+Com+PxDu1    bohccuideameguin
# N+Pl+Com+PxDu2   bohccuideatteguin
# N+Pl+Com+PxDu3  bohccuideaskkaguin
# N+Pl+Com+PxPl1   bohccuideametguin
# N+Pl+Com+PxPl2  bohccuideattetguin
# N+Pl+Com+PxPl3   bohccuideasetguin
# N+Ess+PxSg1               boazunan
# N+Ess+PxSg2               boazunat
# N+Ess+PxSg3               boazunis
# N+Ess+PxDu1             boazuneame
# N+Ess+PxDu2            boazuneatte
# N+Ess+PxDu3           boazuneaskka
# N+Ess+PxPl1            boazuneamet
# N+Ess+PxPl2           boazuneattet
# N+Ess+PxPl3            boazuneaset
#
# [121 rows x 1 columns]

# %%
nb.unigram('lea', lang='sme', period=(1900, 2020))
# Out:
#           0
# 1938      1
# 1959      6
# 1962      1
# 1979   1251
# 1980   1611
# 1981   1050
# 1982   1624
# 1983   2309
# 1984   9209
# 1985   2092
# 1986   3283
# 1987   3741
# 1988   1521
# 1989   1216
# 1990   4037
# 1991   7839
# 1992  12028
# 1993   6222
# 1994   5631
# 1995   8034
# 1996   7768
# 1997  11493
# 1998  13589
# 1999   6893
# 2000   8692
# 2001  11165
# 2002  10972
# 2003  10221
# 2004   5874
# 2005   7795
# 2006   6920
# 2007   8146
# 2008  12320
# 2009  11690
# 2010  11992
# 2011  15116
# 2012   1804
# 2013    486
# 2014     36
# 2016     64

# %%
form_distribution(være)
# Out:
# med belegg: 61 uten belegg: 4
#                     0                 1              2              3  \
# lea     V+Ind+Prs+Sg3
# leat            V+Inf     V+Ind+Prs+Sg2  V+Ind+Prs+Pl1  V+Ind+Prs+Pl3
# lei     V+Ind+Prt+Sg3
# ledje   V+Ind+Prt+Pl3
# lean    V+Ind+Prs+Sg1  V+Ind+Prt+ConNeg
# leai    V+Ind+Prt+Sg3
# ledjen  V+Ind+Prt+Sg1
# leigga  V+Ind+Prt+Du3
# leamaš       V+PrfPrc
# leaba   V+Ind+Prs+Du3
#
#                        4
# lea
# leat    V+Ind+Prs+ConNeg
# lei
# ledje
# lean
# leai
# ledjen
# leigga
# leamaš
# leaba

# %%
(nb.unigram('bivdit', lang='sme', period=(1970, 2020))/nb.unigram('leat', lang='sme', period=(1970,2020))).plot()

# %%
fisk_v_df.head(5).index
# Out:
# Index(['bivdit', 'bivddán', 'bivddát', 'bivdá', 'bivde'], dtype='object')

# %%
rein_n_df.index
# Out:
# Index(['N+Sg+Nom', 'N+Sg+Gen', 'N+Sg+Acc', 'N+Sg+Ill', 'N+Sg+Loc', 'N+Sg+Com',
#        'N+Pl+Nom', 'N+Pl+Gen', 'N+Pl+Acc', 'N+Pl+Ill',
#        ...
#        'N+Pl+Com+PxPl3', 'N+Ess+PxSg1', 'N+Ess+PxSg2', 'N+Ess+PxSg3',
#        'N+Ess+PxDu1', 'N+Ess+PxDu2', 'N+Ess+PxDu3', 'N+Ess+PxPl1',
#        'N+Ess+PxPl2', 'N+Ess+PxPl3'],
#       dtype='object', length=121)

# %%
distribution(rein_n.values(), tot_sami)
# Out:
# med belegg: 25 uten belegg: 55
#                    counts
# bohccuid             2960
# bohccot              2352
# bohcco               2336
# boazu                2259
# bohccos               436
# bohccuiguin           423
# bohccuin              337
# bohccuide             282
# bohccui               172
# bohccuideaset         101
# bohccuidis             91
# boazun                 70
# bohccuideasetguin      60
# bohccuidisguin         26
# bohccuidan             13
# bohccon                 4
# bohccuineaset           4
# bohccuideamet           4
# bohccuidasas            4
# bohccuideaskka          3
# bohccuidanguin          3
# bohccuinis              3
# bohccuidat              3
# bohccuidasaset          2
# bohccuidatguin          1

# %%
smør = word_info('vuodja', pos='N')
smør
# Out:
# {'N+Sg+Nom': ['vuodja'],
#  'N+Sg+Gen': ['vuoja'],
#  'N+Sg+Gen+Allegro': ['vuoja'],
#  'N+Sg+Acc': ['vuoja'],
#  'N+Sg+Ill': ['vudjii'],
#  'N+Sg+Loc': ['vuojas'],
#  'N+Sg+Com': ['vuojain'],
#  'N+Pl+Nom': ['vuojat'],
#  'N+Pl+Gen': ['vuojaid'],
#  'N+Pl+Acc': ['vuojaid'],
#  'N+Pl+Ill': ['vuojaide'],
#  'N+Pl+Loc': ['vuojain'],
#  'N+Pl+Com': ['vuojaiguin'],
#  'N+Ess': ['vuodjan'],
#  'N+Sg+Nom+PxSg1': ['vuodjan'],
#  'N+Sg+Nom+PxSg2': ['vuodjat'],
#  'N+Sg+Nom+PxDu1': ['vuodjame'],
#  'N+Sg+Nom+PxDu2': ['vuodjade'],
#  'N+Sg+Nom+PxPl1': ['vuodjamet'],
#  'N+Sg+Nom+PxPl2': ['vuodjadet'],
#  'N+Sg+Gen+PxSg1': ['vuodjan'],
#  'N+Sg+Gen+PxSg2': ['vuojat'],
#  'N+Sg+Gen+PxSg3': ['vuojas'],
#  'N+Sg+Gen+PxDu1': ['vuodjame'],
#  'N+Sg+Gen+PxDu2': ['vuojade'],
#  'N+Sg+Gen+PxDu3': ['vuojaska'],
#  'N+Sg+Gen+PxPl1': ['vuodjamet'],
#  'N+Sg+Gen+PxPl2': ['vuojadet'],
#  'N+Sg+Gen+PxPl3': ['vuojaset'],
#  'N+Sg+Acc+PxSg1': ['vuodjan'],
#  'N+Sg+Acc+PxSg2': ['vuojat'],
#  'N+Sg+Acc+PxSg3': ['vuojas'],
#  'N+Sg+Acc+PxDu1': ['vuodjame'],
#  'N+Sg+Acc+PxDu2': ['vuojade'],
#  'N+Sg+Acc+PxDu3': ['vuojaska'],
#  'N+Sg+Acc+PxPl1': ['vuodjamet'],
#  'N+Sg+Acc+PxPl2': ['vuojadet'],
#  'N+Sg+Acc+PxPl3': ['vuojaset'],
#  'N+Sg+Ill+PxSg1': ['vuodjasan'],
#  'N+Sg+Ill+PxSg2': ['vuodjasat'],
#  'N+Sg+Ill+PxSg3': ['vuodjasis'],
#  'N+Sg+Ill+PxDu1': ['vuodjaseame'],
#  'N+Sg+Ill+PxDu2': ['vuodjaseatte'],
#  'N+Sg+Ill+PxDu3': ['vuodjaseaskka'],
#  'N+Sg+Ill+PxPl1': ['vuodjaseamet'],
#  'N+Sg+Ill+PxPl2': ['vuodjaseattet'],
#  'N+Sg+Ill+PxPl3': ['vuodjaseaset'],
#  'N+Sg+Loc+PxSg1': ['vuojastan'],
#  'N+Sg+Loc+PxSg2': ['vuojastat'],
#  'N+Sg+Loc+PxSg3': ['vuojastis'],
#  'N+Sg+Loc+PxDu1': ['vuojasteame'],
#  'N+Sg+Loc+PxDu2': ['vuojasteatte'],
#  'N+Sg+Loc+PxDu3': ['vuojasteaskka'],
#  'N+Sg+Loc+PxPl1': ['vuojasteamet'],
#  'N+Sg+Loc+PxPl2': ['vuojasteattet'],
#  'N+Sg+Loc+PxPl3': ['vuojasteaset'],
#  'N+Sg+Com+PxSg1': ['vuojainan'],
#  'N+Sg+Com+PxSg2': ['vuojainat'],
#  'N+Sg+Com+PxSg3': ['vuojainis'],
#  'N+Sg+Com+PxDu1': ['vuojaineame'],
#  'N+Sg+Com+PxDu2': ['vuojaineatte'],
#  'N+Sg+Com+PxDu3': ['vuojaineaskka'],
#  'N+Sg+Com+PxPl1': ['vuojaineamet'],
#  'N+Sg+Com+PxPl2': ['vuojaineattet'],
#  'N+Sg+Com+PxPl3': ['vuojaineaset'],
#  'N+Pl+Gen+PxSg1': ['vuojaidan'],
#  'N+Pl+Gen+PxSg2': ['vuojaidat'],
#  'N+Pl+Gen+PxSg3': ['vuojaidis'],
#  'N+Pl+Gen+PxDu1': ['vuojaideame'],
#  'N+Pl+Gen+PxDu2': ['vuojaideatte'],
#  'N+Pl+Gen+PxDu3': ['vuojaideaskka'],
#  'N+Pl+Gen+PxPl1': ['vuojaideamet'],
#  'N+Pl+Gen+PxPl2': ['vuojaideattet'],
#  'N+Pl+Gen+PxPl3': ['vuojaideaset'],
#  'N+Pl+Acc+PxSg1': ['vuojaidan'],
#  'N+Pl+Acc+PxSg2': ['vuojaidat'],
#  'N+Pl+Acc+PxSg3': ['vuojaidis'],
#  'N+Pl+Acc+PxDu1': ['vuojaideame'],
#  'N+Pl+Acc+PxDu2': ['vuojaideatte'],
#  'N+Pl+Acc+PxDu3': ['vuojaideaskka'],
#  'N+Pl+Acc+PxPl1': ['vuojaideamet'],
#  'N+Pl+Acc+PxPl2': ['vuojaideattet'],
#  'N+Pl+Acc+PxPl3': ['vuojaideaset'],
#  'N+Pl+Ill+PxSg1': ['vuojaidasan'],
#  'N+Pl+Ill+PxSg2': ['vuojaidasat'],
#  'N+Pl+Ill+PxSg3': ['vuojaidasas'],
#  'N+Pl+Ill+PxDu1': ['vuojaidasame'],
#  'N+Pl+Ill+PxDu2': ['vuojaidasade'],
#  'N+Pl+Ill+PxDu3': ['vuojaidasaska'],
#  'N+Pl+Ill+PxPl1': ['vuojaidasamet'],
#  'N+Pl+Ill+PxPl2': ['vuojaidasadet'],
#  'N+Pl+Ill+PxPl3': ['vuojaidasaset'],
#  'N+Pl+Loc+PxSg1': ['vuojainan'],
#  'N+Pl+Loc+PxSg2': ['vuojainat'],
#  'N+Pl+Loc+PxSg3': ['vuojainis'],
#  'N+Pl+Loc+PxDu1': ['vuojaineame'],
#  'N+Pl+Loc+PxDu2': ['vuojaineatte'],
#  'N+Pl+Loc+PxDu3': ['vuojaineaskka'],
#  'N+Pl+Loc+PxPl1': ['vuojaineamet'],
#  'N+Pl+Loc+PxPl2': ['vuojaineattet'],
#  'N+Pl+Loc+PxPl3': ['vuojaineaset'],
#  'N+Pl+Com+PxSg1': ['vuojaidanguin'],
#  'N+Pl+Com+PxSg2': ['vuojaidatguin'],
#  'N+Pl+Com+PxSg3': ['vuojaidisguin'],
#  'N+Pl+Com+PxDu1': ['vuojaideameguin'],
#  'N+Pl+Com+PxDu2': ['vuojaideatteguin'],
#  'N+Pl+Com+PxDu3': ['vuojaideaskkaguin'],
#  'N+Pl+Com+PxPl1': ['vuojaideametguin'],
#  'N+Pl+Com+PxPl2': ['vuojaideattetguin'],
#  'N+Pl+Com+PxPl3': ['vuojaideasetguin'],
#  'N+Ess+PxSg1': ['vuodjanan'],
#  'N+Ess+PxSg2': ['vuodjanat'],
#  'N+Ess+PxSg3': ['vuodjanis'],
#  'N+Ess+PxDu1': ['vuodjaneame'],
#  'N+Ess+PxDu2': ['vuodjaneatte'],
#  'N+Ess+PxDu3': ['vuodjaneaskka'],
#  'N+Ess+PxPl1': ['vuodjaneamet'],
#  'N+Ess+PxPl2': ['vuodjaneattet'],
#  'N+Ess+PxPl3': ['vuodjaneaset']}

# %%
smør2 = word_info('gusavuodja', pos='N')
smør2
# Out:
# {'N+Sg+Nom': ['gusavuodja'],
#  'N+Sg+Gen': ['gusavuoja'],
#  'N+Sg+Gen+Allegro': ['gusavuoja'],
#  'N+Sg+Acc': ['gusavuoja'],
#  'N+Sg+Ill': ['gusavudjii'],
#  'N+Sg+Loc': ['gusavuojas'],
#  'N+Sg+Com': ['gusavuojain'],
#  'N+Pl+Nom': ['gusavuojat'],
#  'N+Pl+Gen': ['gusavuojaid'],
#  'N+Pl+Acc': ['gusavuojaid'],
#  'N+Pl+Ill': ['gusavuojaide'],
#  'N+Pl+Loc': ['gusavuojain'],
#  'N+Pl+Com': ['gusavuojaiguin'],
#  'N+Ess': ['gusavuodjan'],
#  'N+Sg+Nom+PxSg1': ['gusavuodjan'],
#  'N+Sg+Nom+PxSg2': ['gusavuodjat'],
#  'N+Sg+Nom+PxDu1': ['gusavuodjame'],
#  'N+Sg+Nom+PxDu2': ['gusavuodjade'],
#  'N+Sg+Nom+PxPl1': ['gusavuodjamet'],
#  'N+Sg+Nom+PxPl2': ['gusavuodjadet'],
#  'N+Sg+Gen+PxSg1': ['gusavuodjan'],
#  'N+Sg+Gen+PxSg2': ['gusavuojat'],
#  'N+Sg+Gen+PxSg3': ['gusavuojas'],
#  'N+Sg+Gen+PxDu1': ['gusavuodjame'],
#  'N+Sg+Gen+PxDu2': ['gusavuojade'],
#  'N+Sg+Gen+PxDu3': ['gusavuojaska'],
#  'N+Sg+Gen+PxPl1': ['gusavuodjamet'],
#  'N+Sg+Gen+PxPl2': ['gusavuojadet'],
#  'N+Sg+Gen+PxPl3': ['gusavuojaset'],
#  'N+Sg+Acc+PxSg1': ['gusavuodjan'],
#  'N+Sg+Acc+PxSg2': ['gusavuojat'],
#  'N+Sg+Acc+PxSg3': ['gusavuojas'],
#  'N+Sg+Acc+PxDu1': ['gusavuodjame'],
#  'N+Sg+Acc+PxDu2': ['gusavuojade'],
#  'N+Sg+Acc+PxDu3': ['gusavuojaska'],
#  'N+Sg+Acc+PxPl1': ['gusavuodjamet'],
#  'N+Sg+Acc+PxPl2': ['gusavuojadet'],
#  'N+Sg+Acc+PxPl3': ['gusavuojaset'],
#  'N+Sg+Ill+PxSg1': ['gusavuodjasan'],
#  'N+Sg+Ill+PxSg2': ['gusavuodjasat'],
#  'N+Sg+Ill+PxSg3': ['gusavuodjasis'],
#  'N+Sg+Ill+PxDu1': ['gusavuodjaseame'],
#  'N+Sg+Ill+PxDu2': ['gusavuodjaseatte'],
#  'N+Sg+Ill+PxDu3': ['gusavuodjaseaskka'],
#  'N+Sg+Ill+PxPl1': ['gusavuodjaseamet'],
#  'N+Sg+Ill+PxPl2': ['gusavuodjaseattet'],
#  'N+Sg+Ill+PxPl3': ['gusavuodjaseaset'],
#  'N+Sg+Loc+PxSg1': ['gusavuojastan'],
#  'N+Sg+Loc+PxSg2': ['gusavuojastat'],
#  'N+Sg+Loc+PxSg3': ['gusavuojastis'],
#  'N+Sg+Loc+PxDu1': ['gusavuojasteame'],
#  'N+Sg+Loc+PxDu2': ['gusavuojasteatte'],
#  'N+Sg+Loc+PxDu3': ['gusavuojasteaskka'],
#  'N+Sg+Loc+PxPl1': ['gusavuojasteamet'],
#  'N+Sg+Loc+PxPl2': ['gusavuojasteattet'],
#  'N+Sg+Loc+PxPl3': ['gusavuojasteaset'],
#  'N+Sg+Com+PxSg1': ['gusavuojainan'],
#  'N+Sg+Com+PxSg2': ['gusavuojainat'],
#  'N+Sg+Com+PxSg3': ['gusavuojainis'],
#  'N+Sg+Com+PxDu1': ['gusavuojaineame'],
#  'N+Sg+Com+PxDu2': ['gusavuojaineatte'],
#  'N+Sg+Com+PxDu3': ['gusavuojaineaskka'],
#  'N+Sg+Com+PxPl1': ['gusavuojaineamet'],
#  'N+Sg+Com+PxPl2': ['gusavuojaineattet'],
#  'N+Sg+Com+PxPl3': ['gusavuojaineaset'],
#  'N+Pl+Gen+PxSg1': ['gusavuojaidan'],
#  'N+Pl+Gen+PxSg2': ['gusavuojaidat'],
#  'N+Pl+Gen+PxSg3': ['gusavuojaidis'],
#  'N+Pl+Gen+PxDu1': ['gusavuojaideame'],
#  'N+Pl+Gen+PxDu2': ['gusavuojaideatte'],
#  'N+Pl+Gen+PxDu3': ['gusavuojaideaskka'],
#  'N+Pl+Gen+PxPl1': ['gusavuojaideamet'],
#  'N+Pl+Gen+PxPl2': ['gusavuojaideattet'],
#  'N+Pl+Gen+PxPl3': ['gusavuojaideaset'],
#  'N+Pl+Acc+PxSg1': ['gusavuojaidan'],
#  'N+Pl+Acc+PxSg2': ['gusavuojaidat'],
#  'N+Pl+Acc+PxSg3': ['gusavuojaidis'],
#  'N+Pl+Acc+PxDu1': ['gusavuojaideame'],
#  'N+Pl+Acc+PxDu2': ['gusavuojaideatte'],
#  'N+Pl+Acc+PxDu3': ['gusavuojaideaskka'],
#  'N+Pl+Acc+PxPl1': ['gusavuojaideamet'],
#  'N+Pl+Acc+PxPl2': ['gusavuojaideattet'],
#  'N+Pl+Acc+PxPl3': ['gusavuojaideaset'],
#  'N+Pl+Ill+PxSg1': ['gusavuojaidasan'],
#  'N+Pl+Ill+PxSg2': ['gusavuojaidasat'],
#  'N+Pl+Ill+PxSg3': ['gusavuojaidasas'],
#  'N+Pl+Ill+PxDu1': ['gusavuojaidasame'],
#  'N+Pl+Ill+PxDu2': ['gusavuojaidasade'],
#  'N+Pl+Ill+PxDu3': ['gusavuojaidasaska'],
#  'N+Pl+Ill+PxPl1': ['gusavuojaidasamet'],
#  'N+Pl+Ill+PxPl2': ['gusavuojaidasadet'],
#  'N+Pl+Ill+PxPl3': ['gusavuojaidasaset'],
#  'N+Pl+Loc+PxSg1': ['gusavuojainan'],
#  'N+Pl+Loc+PxSg2': ['gusavuojainat'],
#  'N+Pl+Loc+PxSg3': ['gusavuojainis'],
#  'N+Pl+Loc+PxDu1': ['gusavuojaineame'],
#  'N+Pl+Loc+PxDu2': ['gusavuojaineatte'],
#  'N+Pl+Loc+PxDu3': ['gusavuojaineaskka'],
#  'N+Pl+Loc+PxPl1': ['gusavuojaineamet'],
#  'N+Pl+Loc+PxPl2': ['gusavuojaineattet'],
#  'N+Pl+Loc+PxPl3': ['gusavuojaineaset'],
#  'N+Pl+Com+PxSg1': ['gusavuojaidanguin'],
#  'N+Pl+Com+PxSg2': ['gusavuojaidatguin'],
#  'N+Pl+Com+PxSg3': ['gusavuojaidisguin'],
#  'N+Pl+Com+PxDu1': ['gusavuojaideameguin'],
#  'N+Pl+Com+PxDu2': ['gusavuojaideatteguin'],
#  'N+Pl+Com+PxDu3': ['gusavuojaideaskkaguin'],
#  'N+Pl+Com+PxPl1': ['gusavuojaideametguin'],
#  'N+Pl+Com+PxPl2': ['gusavuojaideattetguin'],
#  'N+Pl+Com+PxPl3': ['gusavuojaideasetguin'],
#  'N+Ess+PxSg1': ['gusavuodjanan'],
#  'N+Ess+PxSg2': ['gusavuodjanat'],
#  'N+Ess+PxSg3': ['gusavuodjanis'],
#  'N+Ess+PxDu1': ['gusavuodjaneame'],
#  'N+Ess+PxDu2': ['gusavuodjaneatte'],
#  'N+Ess+PxDu3': ['gusavuodjaneaskka'],
#  'N+Ess+PxPl1': ['gusavuodjaneamet'],
#  'N+Ess+PxPl2': ['gusavuodjaneattet'],
#  'N+Ess+PxPl3': ['gusavuodjaneaset']}

# %%
fett = word_info('buoidi', pos='N')
fett
# Out:
# {'N+Sg+Nom': ['buoidi'],
#  'N+Sg+Gen': ['buoidde', 'buoiddi'],
#  'N+Sg+Gen+Allegro': ['buoidde'],
#  'N+Sg+Acc': ['buoiddi'],
#  'N+Sg+Ill': ['buoidái'],
#  'N+Sg+Loc': ['buoiddis'],
#  'N+Sg+Com': ['buiddiin'],
#  'N+Pl+Nom': ['buoiddit'],
#  'N+Pl+Gen': ['buiddiid'],
#  'N+Pl+Acc': ['buiddiid'],
#  'N+Pl+Ill': ['buiddiide'],
#  'N+Pl+Loc': ['buiddiin'],
#  'N+Pl+Com': ['buiddiiguin'],
#  'N+Ess': ['buoidin'],
#  'N+Sg+Nom+PxSg1': ['buoidán'],
#  'N+Sg+Nom+PxSg2': ['buoidát'],
#  'N+Sg+Nom+PxDu1': ['buoidáme'],
#  'N+Sg+Nom+PxDu2': ['buoidáde'],
#  'N+Sg+Nom+PxPl1': ['buoidámet'],
#  'N+Sg+Nom+PxPl2': ['buoidádet'],
#  'N+Sg+Gen+PxSg1': ['buoidán'],
#  'N+Sg+Gen+PxSg2': ['buoiddát'],
#  'N+Sg+Gen+PxSg3': ['buoiddis'],
#  'N+Sg+Gen+PxDu1': ['buoidáme'],
#  'N+Sg+Gen+PxDu2': ['buoiddáde'],
#  'N+Sg+Gen+PxDu3': ['buoiddiska'],
#  'N+Sg+Gen+PxPl1': ['buoidámet'],
#  'N+Sg+Gen+PxPl2': ['buoiddádet'],
#  'N+Sg+Gen+PxPl3': ['buoiddiset'],
#  'N+Sg+Acc+PxSg1': ['buoidán'],
#  'N+Sg+Acc+PxSg2': ['buoiddát'],
#  'N+Sg+Acc+PxSg3': ['buoiddis'],
#  'N+Sg+Acc+PxDu1': ['buoidáme'],
#  'N+Sg+Acc+PxDu2': ['buoiddáde'],
#  'N+Sg+Acc+PxDu3': ['buoiddiska'],
#  'N+Sg+Acc+PxPl1': ['buoidámet'],
#  'N+Sg+Acc+PxPl2': ['buoiddádet'],
#  'N+Sg+Acc+PxPl3': ['buoiddiset'],
#  'N+Sg+Ill+PxSg1': ['buoidásan'],
#  'N+Sg+Ill+PxSg2': ['buoidásat'],
#  'N+Sg+Ill+PxSg3': ['buoidásis'],
#  'N+Sg+Ill+PxDu1': ['buoidáseame'],
#  'N+Sg+Ill+PxDu2': ['buoidáseatte'],
#  'N+Sg+Ill+PxDu3': ['buoidáseaskka'],
#  'N+Sg+Ill+PxPl1': ['buoidáseamet'],
#  'N+Sg+Ill+PxPl2': ['buoidáseattet'],
#  'N+Sg+Ill+PxPl3': ['buoidáseaset'],
#  'N+Sg+Loc+PxSg1': ['buoiddistan'],
#  'N+Sg+Loc+PxSg2': ['buoiddistat'],
#  'N+Sg+Loc+PxSg3': ['buoiddistis'],
#  'N+Sg+Loc+PxDu1': ['buoiddisteame'],
#  'N+Sg+Loc+PxDu2': ['buoiddisteatte'],
#  'N+Sg+Loc+PxDu3': ['buoiddisteaskka'],
#  'N+Sg+Loc+PxPl1': ['buoiddisteamet'],
#  'N+Sg+Loc+PxPl2': ['buoiddisteattet'],
#  'N+Sg+Loc+PxPl3': ['buoiddisteaset'],
#  'N+Sg+Com+PxSg1': ['buiddiinan'],
#  'N+Sg+Com+PxSg2': ['buiddiinat'],
#  'N+Sg+Com+PxSg3': ['buiddiinis'],
#  'N+Sg+Com+PxDu1': ['buiddiineame'],
#  'N+Sg+Com+PxDu2': ['buiddiineatte'],
#  'N+Sg+Com+PxDu3': ['buiddiineaskka'],
#  'N+Sg+Com+PxPl1': ['buiddiineamet'],
#  'N+Sg+Com+PxPl2': ['buiddiineattet'],
#  'N+Sg+Com+PxPl3': ['buiddiineaset'],
#  'N+Pl+Gen+PxSg1': ['buiddiidan'],
#  'N+Pl+Gen+PxSg2': ['buiddiidat'],
#  'N+Pl+Gen+PxSg3': ['buiddiidis'],
#  'N+Pl+Gen+PxDu1': ['buiddiideame'],
#  'N+Pl+Gen+PxDu2': ['buiddiideatte'],
#  'N+Pl+Gen+PxDu3': ['buiddiideaskka'],
#  'N+Pl+Gen+PxPl1': ['buiddiideamet'],
#  'N+Pl+Gen+PxPl2': ['buiddiideattet'],
#  'N+Pl+Gen+PxPl3': ['buiddiideaset'],
#  'N+Pl+Acc+PxSg1': ['buiddiidan'],
#  'N+Pl+Acc+PxSg2': ['buiddiidat'],
#  'N+Pl+Acc+PxSg3': ['buiddiidis'],
#  'N+Pl+Acc+PxDu1': ['buiddiideame'],
#  'N+Pl+Acc+PxDu2': ['buiddiideatte'],
#  'N+Pl+Acc+PxDu3': ['buiddiideaskka'],
#  'N+Pl+Acc+PxPl1': ['buiddiideamet'],
#  'N+Pl+Acc+PxPl2': ['buiddiideattet'],
#  'N+Pl+Acc+PxPl3': ['buiddiideaset'],
#  'N+Pl+Ill+PxSg1': ['buiddiidasan'],
#  'N+Pl+Ill+PxSg2': ['buiddiidasat'],
#  'N+Pl+Ill+PxSg3': ['buiddiidasas'],
#  'N+Pl+Ill+PxDu1': ['buiddiidasame'],
#  'N+Pl+Ill+PxDu2': ['buiddiidasade'],
#  'N+Pl+Ill+PxDu3': ['buiddiidasaska'],
#  'N+Pl+Ill+PxPl1': ['buiddiidasamet'],
#  'N+Pl+Ill+PxPl2': ['buiddiidasadet'],
#  'N+Pl+Ill+PxPl3': ['buiddiidasaset'],
#  'N+Pl+Loc+PxSg1': ['buiddiinan'],
#  'N+Pl+Loc+PxSg2': ['buiddiinat'],
#  'N+Pl+Loc+PxSg3': ['buiddiinis'],
#  'N+Pl+Loc+PxDu1': ['buiddiineame'],
#  'N+Pl+Loc+PxDu2': ['buiddiineatte'],
#  'N+Pl+Loc+PxDu3': ['buiddiineaskka'],
#  'N+Pl+Loc+PxPl1': ['buiddiineamet'],
#  'N+Pl+Loc+PxPl2': ['buiddiineattet'],
#  'N+Pl+Loc+PxPl3': ['buiddiineaset'],
#  'N+Pl+Com+PxSg1': ['buiddiidanguin'],
#  'N+Pl+Com+PxSg2': ['buiddiidatguin'],
#  'N+Pl+Com+PxSg3': ['buiddiidisguin'],
#  'N+Pl+Com+PxDu1': ['buiddiideameguin'],
#  'N+Pl+Com+PxDu2': ['buiddiideatteguin'],
#  'N+Pl+Com+PxDu3': ['buiddiideaskkaguin'],
#  'N+Pl+Com+PxPl1': ['buiddiideametguin'],
#  'N+Pl+Com+PxPl2': ['buiddiideattetguin'],
#  'N+Pl+Com+PxPl3': ['buiddiideasetguin'],
#  'N+Ess+PxSg1': ['buoidinan'],
#  'N+Ess+PxSg2': ['buoidinat'],
#  'N+Ess+PxSg3': ['buoidinis'],
#  'N+Ess+PxDu1': ['buoidineame'],
#  'N+Ess+PxDu2': ['buoidineatte'],
#  'N+Ess+PxDu3': ['buoidineaskka'],
#  'N+Ess+PxPl1': ['buoidineamet'],
#  'N+Ess+PxPl2': ['buoidineattet'],
#  'N+Ess+PxPl3': ['buoidineaset']}

# %%
fett2 = word_info('sisbuoiddit', pos='N')
fett2
# Out:
# {'N+Sg+Nom': ['sisbuoidi'],
#  'N+Sg+Gen': ['sisbuoidde', 'sisbuoiddi'],
#  'N+Sg+Gen+Allegro': ['sisbuoidde'],
#  'N+Sg+Acc': ['sisbuoiddi'],
#  'N+Sg+Ill': ['sisbuoidái'],
#  'N+Sg+Loc': ['sisbuoiddis'],
#  'N+Sg+Com': ['sisbuiddiin'],
#  'N+Pl+Nom': ['sisbuoiddit'],
#  'N+Pl+Gen': ['sisbuiddiid'],
#  'N+Pl+Acc': ['sisbuiddiid'],
#  'N+Pl+Ill': ['sisbuiddiide'],
#  'N+Pl+Loc': ['sisbuiddiin'],
#  'N+Pl+Com': ['sisbuiddiiguin'],
#  'N+Ess': ['sisbuoidin'],
#  'N+Sg+Nom+PxSg1': ['sisbuoidán'],
#  'N+Sg+Nom+PxSg2': ['sisbuoidát'],
#  'N+Sg+Nom+PxDu1': ['sisbuoidáme'],
#  'N+Sg+Nom+PxDu2': ['sisbuoidáde'],
#  'N+Sg+Nom+PxPl1': ['sisbuoidámet'],
#  'N+Sg+Nom+PxPl2': ['sisbuoidádet'],
#  'N+Sg+Gen+PxSg1': ['sisbuoidán'],
#  'N+Sg+Gen+PxSg2': ['sisbuoiddát'],
#  'N+Sg+Gen+PxSg3': ['sisbuoiddis'],
#  'N+Sg+Gen+PxDu1': ['sisbuoidáme'],
#  'N+Sg+Gen+PxDu2': ['sisbuoiddáde'],
#  'N+Sg+Gen+PxDu3': ['sisbuoiddiska'],
#  'N+Sg+Gen+PxPl1': ['sisbuoidámet'],
#  'N+Sg+Gen+PxPl2': ['sisbuoiddádet'],
#  'N+Sg+Gen+PxPl3': ['sisbuoiddiset'],
#  'N+Sg+Acc+PxSg1': ['sisbuoidán'],
#  'N+Sg+Acc+PxSg2': ['sisbuoiddát'],
#  'N+Sg+Acc+PxSg3': ['sisbuoiddis'],
#  'N+Sg+Acc+PxDu1': ['sisbuoidáme'],
#  'N+Sg+Acc+PxDu2': ['sisbuoiddáde'],
#  'N+Sg+Acc+PxDu3': ['sisbuoiddiska'],
#  'N+Sg+Acc+PxPl1': ['sisbuoidámet'],
#  'N+Sg+Acc+PxPl2': ['sisbuoiddádet'],
#  'N+Sg+Acc+PxPl3': ['sisbuoiddiset'],
#  'N+Sg+Ill+PxSg1': ['sisbuoidásan'],
#  'N+Sg+Ill+PxSg2': ['sisbuoidásat'],
#  'N+Sg+Ill+PxSg3': ['sisbuoidásis'],
#  'N+Sg+Ill+PxDu1': ['sisbuoidáseame'],
#  'N+Sg+Ill+PxDu2': ['sisbuoidáseatte'],
#  'N+Sg+Ill+PxDu3': ['sisbuoidáseaskka'],
#  'N+Sg+Ill+PxPl1': ['sisbuoidáseamet'],
#  'N+Sg+Ill+PxPl2': ['sisbuoidáseattet'],
#  'N+Sg+Ill+PxPl3': ['sisbuoidáseaset'],
#  'N+Sg+Loc+PxSg1': ['sisbuoiddistan'],
#  'N+Sg+Loc+PxSg2': ['sisbuoiddistat'],
#  'N+Sg+Loc+PxSg3': ['sisbuoiddistis'],
#  'N+Sg+Loc+PxDu1': ['sisbuoiddisteame'],
#  'N+Sg+Loc+PxDu2': ['sisbuoiddisteatte'],
#  'N+Sg+Loc+PxDu3': ['sisbuoiddisteaskka'],
#  'N+Sg+Loc+PxPl1': ['sisbuoiddisteamet'],
#  'N+Sg+Loc+PxPl2': ['sisbuoiddisteattet'],
#  'N+Sg+Loc+PxPl3': ['sisbuoiddisteaset'],
#  'N+Sg+Com+PxSg1': ['sisbuiddiinan'],
#  'N+Sg+Com+PxSg2': ['sisbuiddiinat'],
#  'N+Sg+Com+PxSg3': ['sisbuiddiinis'],
#  'N+Sg+Com+PxDu1': ['sisbuiddiineame'],
#  'N+Sg+Com+PxDu2': ['sisbuiddiineatte'],
#  'N+Sg+Com+PxDu3': ['sisbuiddiineaskka'],
#  'N+Sg+Com+PxPl1': ['sisbuiddiineamet'],
#  'N+Sg+Com+PxPl2': ['sisbuiddiineattet'],
#  'N+Sg+Com+PxPl3': ['sisbuiddiineaset'],
#  'N+Pl+Gen+PxSg1': ['sisbuiddiidan'],
#  'N+Pl+Gen+PxSg2': ['sisbuiddiidat'],
#  'N+Pl+Gen+PxSg3': ['sisbuiddiidis'],
#  'N+Pl+Gen+PxDu1': ['sisbuiddiideame'],
#  'N+Pl+Gen+PxDu2': ['sisbuiddiideatte'],
#  'N+Pl+Gen+PxDu3': ['sisbuiddiideaskka'],
#  'N+Pl+Gen+PxPl1': ['sisbuiddiideamet'],
#  'N+Pl+Gen+PxPl2': ['sisbuiddiideattet'],
#  'N+Pl+Gen+PxPl3': ['sisbuiddiideaset'],
#  'N+Pl+Acc+PxSg1': ['sisbuiddiidan'],
#  'N+Pl+Acc+PxSg2': ['sisbuiddiidat'],
#  'N+Pl+Acc+PxSg3': ['sisbuiddiidis'],
#  'N+Pl+Acc+PxDu1': ['sisbuiddiideame'],
#  'N+Pl+Acc+PxDu2': ['sisbuiddiideatte'],
#  'N+Pl+Acc+PxDu3': ['sisbuiddiideaskka'],
#  'N+Pl+Acc+PxPl1': ['sisbuiddiideamet'],
#  'N+Pl+Acc+PxPl2': ['sisbuiddiideattet'],
#  'N+Pl+Acc+PxPl3': ['sisbuiddiideaset'],
#  'N+Pl+Ill+PxSg1': ['sisbuiddiidasan'],
#  'N+Pl+Ill+PxSg2': ['sisbuiddiidasat'],
#  'N+Pl+Ill+PxSg3': ['sisbuiddiidasas'],
#  'N+Pl+Ill+PxDu1': ['sisbuiddiidasame'],
#  'N+Pl+Ill+PxDu2': ['sisbuiddiidasade'],
#  'N+Pl+Ill+PxDu3': ['sisbuiddiidasaska'],
#  'N+Pl+Ill+PxPl1': ['sisbuiddiidasamet'],
#  'N+Pl+Ill+PxPl2': ['sisbuiddiidasadet'],
#  'N+Pl+Ill+PxPl3': ['sisbuiddiidasaset'],
#  'N+Pl+Loc+PxSg1': ['sisbuiddiinan'],
#  'N+Pl+Loc+PxSg2': ['sisbuiddiinat'],
#  'N+Pl+Loc+PxSg3': ['sisbuiddiinis'],
#  'N+Pl+Loc+PxDu1': ['sisbuiddiineame'],
#  'N+Pl+Loc+PxDu2': ['sisbuiddiineatte'],
#  'N+Pl+Loc+PxDu3': ['sisbuiddiineaskka'],
#  'N+Pl+Loc+PxPl1': ['sisbuiddiineamet'],
#  'N+Pl+Loc+PxPl2': ['sisbuiddiineattet'],
#  'N+Pl+Loc+PxPl3': ['sisbuiddiineaset'],
#  'N+Pl+Com+PxSg1': ['sisbuiddiidanguin'],
#  'N+Pl+Com+PxSg2': ['sisbuiddiidatguin'],
#  'N+Pl+Com+PxSg3': ['sisbuiddiidisguin'],
#  'N+Pl+Com+PxDu1': ['sisbuiddiideameguin'],
#  'N+Pl+Com+PxDu2': ['sisbuiddiideatteguin'],
#  'N+Pl+Com+PxDu3': ['sisbuiddiideaskkaguin'],
#  'N+Pl+Com+PxPl1': ['sisbuiddiideametguin'],
#  'N+Pl+Com+PxPl2': ['sisbuiddiideattetguin'],
#  'N+Pl+Com+PxPl3': ['sisbuiddiideasetguin'],
#  'N+Ess+PxSg1': ['sisbuoidinan'],
#  'N+Ess+PxSg2': ['sisbuoidinat'],
#  'N+Ess+PxSg3': ['sisbuoidinis'],
#  'N+Ess+PxDu1': ['sisbuoidineame'],
#  'N+Ess+PxDu2': ['sisbuoidineatte'],
#  'N+Ess+PxDu3': ['sisbuoidineaskka'],
#  'N+Ess+PxPl1': ['sisbuoidineamet'],
#  'N+Ess+PxPl2': ['sisbuoidineattet'],
#  'N+Ess+PxPl3': ['sisbuoidineaset']}

# %%
distribution(smør2.values(), tot_sami)
# Out:
# med belegg: 6 uten belegg: 76
#              counts
# gusavuoja        27
# gusavuodja       25
# gusavuojain       5
# gusavuojas        2
# gusavuojaid       1
# gusavuodjan       1

# %%
distribution(smør.values(), tot_sami)
# Out:
# med belegg: 13 uten belegg: 69
#                counts
# vuoja             393
# vuodja            324
# vuodjat           210
# vuojas             67
# vuodjan            59
# vuojain            37
# vuojaid            20
# vudjii             18
# vuojat             15
# vuodjame            7
# vuojade             4
# vuojaiguin          2
# vuojaideaskka       1

# %%
distribution(fett.values(), tot_sami)
# Out:
# med belegg: 11 uten belegg: 74
#              counts
# buoidi          494
# buoiddi         184
# buoiddit         71
# buiddiid         52
# buoiddis         32
# buoidde          28
# buiddiin         22
# buoidin          13
# buiddiiguin       3
# buiddiinis        2
# buoidái           1

# %%
distribution(fett2.values(), tot_sami)
# Out:
# med belegg: 0 uten belegg: 85
# Empty DataFrame
# Columns: [counts]
# Index: []

# %%
invert(fett)
# Out:
# {'buoidi': ['N+Sg+Nom'],
#  'buoidde': ['N+Sg+Gen', 'N+Sg+Gen+Allegro'],
#  'buoiddi': ['N+Sg+Gen', 'N+Sg+Acc'],
#  'buoidái': ['N+Sg+Ill'],
#  'buoiddis': ['N+Sg+Loc', 'N+Sg+Gen+PxSg3', 'N+Sg+Acc+PxSg3'],
#  'buiddiin': ['N+Sg+Com', 'N+Pl+Loc'],
#  'buoiddit': ['N+Pl+Nom'],
#  'buiddiid': ['N+Pl+Gen', 'N+Pl+Acc'],
#  'buiddiide': ['N+Pl+Ill'],
#  'buiddiiguin': ['N+Pl+Com'],
#  'buoidin': ['N+Ess'],
#  'buoidán': ['N+Sg+Nom+PxSg1', 'N+Sg+Gen+PxSg1', 'N+Sg+Acc+PxSg1'],
#  'buoidát': ['N+Sg+Nom+PxSg2'],
#  'buoidáme': ['N+Sg+Nom+PxDu1', 'N+Sg+Gen+PxDu1', 'N+Sg+Acc+PxDu1'],
#  'buoidáde': ['N+Sg+Nom+PxDu2'],
#  'buoidámet': ['N+Sg+Nom+PxPl1', 'N+Sg+Gen+PxPl1', 'N+Sg+Acc+PxPl1'],
#  'buoidádet': ['N+Sg+Nom+PxPl2'],
#  'buoiddát': ['N+Sg+Gen+PxSg2', 'N+Sg+Acc+PxSg2'],
#  'buoiddáde': ['N+Sg+Gen+PxDu2', 'N+Sg+Acc+PxDu2'],
#  'buoiddiska': ['N+Sg+Gen+PxDu3', 'N+Sg+Acc+PxDu3'],
#  'buoiddádet': ['N+Sg+Gen+PxPl2', 'N+Sg+Acc+PxPl2'],
#  'buoiddiset': ['N+Sg+Gen+PxPl3', 'N+Sg+Acc+PxPl3'],
#  'buoidásan': ['N+Sg+Ill+PxSg1'],
#  'buoidásat': ['N+Sg+Ill+PxSg2'],
#  'buoidásis': ['N+Sg+Ill+PxSg3'],
#  'buoidáseame': ['N+Sg+Ill+PxDu1'],
#  'buoidáseatte': ['N+Sg+Ill+PxDu2'],
#  'buoidáseaskka': ['N+Sg+Ill+PxDu3'],
#  'buoidáseamet': ['N+Sg+Ill+PxPl1'],
#  'buoidáseattet': ['N+Sg+Ill+PxPl2'],
#  'buoidáseaset': ['N+Sg+Ill+PxPl3'],
#  'buoiddistan': ['N+Sg+Loc+PxSg1'],
#  'buoiddistat': ['N+Sg+Loc+PxSg2'],
#  'buoiddistis': ['N+Sg+Loc+PxSg3'],
#  'buoiddisteame': ['N+Sg+Loc+PxDu1'],
#  'buoiddisteatte': ['N+Sg+Loc+PxDu2'],
#  'buoiddisteaskka': ['N+Sg+Loc+PxDu3'],
#  'buoiddisteamet': ['N+Sg+Loc+PxPl1'],
#  'buoiddisteattet': ['N+Sg+Loc+PxPl2'],
#  'buoiddisteaset': ['N+Sg+Loc+PxPl3'],
#  'buiddiinan': ['N+Sg+Com+PxSg1', 'N+Pl+Loc+PxSg1'],
#  'buiddiinat': ['N+Sg+Com+PxSg2', 'N+Pl+Loc+PxSg2'],
#  'buiddiinis': ['N+Sg+Com+PxSg3', 'N+Pl+Loc+PxSg3'],
#  'buiddiineame': ['N+Sg+Com+PxDu1', 'N+Pl+Loc+PxDu1'],
#  'buiddiineatte': ['N+Sg+Com+PxDu2', 'N+Pl+Loc+PxDu2'],
#  'buiddiineaskka': ['N+Sg+Com+PxDu3', 'N+Pl+Loc+PxDu3'],
#  'buiddiineamet': ['N+Sg+Com+PxPl1', 'N+Pl+Loc+PxPl1'],
#  'buiddiineattet': ['N+Sg+Com+PxPl2', 'N+Pl+Loc+PxPl2'],
#  'buiddiineaset': ['N+Sg+Com+PxPl3', 'N+Pl+Loc+PxPl3'],
#  'buiddiidan': ['N+Pl+Gen+PxSg1', 'N+Pl+Acc+PxSg1'],
#  'buiddiidat': ['N+Pl+Gen+PxSg2', 'N+Pl+Acc+PxSg2'],
#  'buiddiidis': ['N+Pl+Gen+PxSg3', 'N+Pl+Acc+PxSg3'],
#  'buiddiideame': ['N+Pl+Gen+PxDu1', 'N+Pl+Acc+PxDu1'],
#  'buiddiideatte': ['N+Pl+Gen+PxDu2', 'N+Pl+Acc+PxDu2'],
#  'buiddiideaskka': ['N+Pl+Gen+PxDu3', 'N+Pl+Acc+PxDu3'],
#  'buiddiideamet': ['N+Pl+Gen+PxPl1', 'N+Pl+Acc+PxPl1'],
#  'buiddiideattet': ['N+Pl+Gen+PxPl2', 'N+Pl+Acc+PxPl2'],
#  'buiddiideaset': ['N+Pl+Gen+PxPl3', 'N+Pl+Acc+PxPl3'],
#  'buiddiidasan': ['N+Pl+Ill+PxSg1'],
#  'buiddiidasat': ['N+Pl+Ill+PxSg2'],
#  'buiddiidasas': ['N+Pl+Ill+PxSg3'],
#  'buiddiidasame': ['N+Pl+Ill+PxDu1'],
#  'buiddiidasade': ['N+Pl+Ill+PxDu2'],
#  'buiddiidasaska': ['N+Pl+Ill+PxDu3'],
#  'buiddiidasamet': ['N+Pl+Ill+PxPl1'],
#  'buiddiidasadet': ['N+Pl+Ill+PxPl2'],
#  'buiddiidasaset': ['N+Pl+Ill+PxPl3'],
#  'buiddiidanguin': ['N+Pl+Com+PxSg1'],
#  'buiddiidatguin': ['N+Pl+Com+PxSg2'],
#  'buiddiidisguin': ['N+Pl+Com+PxSg3'],
#  'buiddiideameguin': ['N+Pl+Com+PxDu1'],
#  'buiddiideatteguin': ['N+Pl+Com+PxDu2'],
#  'buiddiideaskkaguin': ['N+Pl+Com+PxDu3'],
#  'buiddiideametguin': ['N+Pl+Com+PxPl1'],
#  'buiddiideattetguin': ['N+Pl+Com+PxPl2'],
#  'buiddiideasetguin': ['N+Pl+Com+PxPl3'],
#  'buoidinan': ['N+Ess+PxSg1'],
#  'buoidinat': ['N+Ess+PxSg2'],
#  'buoidinis': ['N+Ess+PxSg3'],
#  'buoidineame': ['N+Ess+PxDu1'],
#  'buoidineatte': ['N+Ess+PxDu2'],
#  'buoidineaskka': ['N+Ess+PxDu3'],
#  'buoidineamet': ['N+Ess+PxPl1'],
#  'buoidineattet': ['N+Ess+PxPl2'],
#  'buoidineaset': ['N+Ess+PxPl3']}

# %%
invert(smør)
# Out:
# {'vuodja': ['N+Sg+Nom'],
#  'vuoja': ['N+Sg+Gen', 'N+Sg+Gen+Allegro', 'N+Sg+Acc'],
#  'vudjii': ['N+Sg+Ill'],
#  'vuojas': ['N+Sg+Loc', 'N+Sg+Gen+PxSg3', 'N+Sg+Acc+PxSg3'],
#  'vuojain': ['N+Sg+Com', 'N+Pl+Loc'],
#  'vuojat': ['N+Pl+Nom', 'N+Sg+Gen+PxSg2', 'N+Sg+Acc+PxSg2'],
#  'vuojaid': ['N+Pl+Gen', 'N+Pl+Acc'],
#  'vuojaide': ['N+Pl+Ill'],
#  'vuojaiguin': ['N+Pl+Com'],
#  'vuodjan': ['N+Ess', 'N+Sg+Nom+PxSg1', 'N+Sg+Gen+PxSg1', 'N+Sg+Acc+PxSg1'],
#  'vuodjat': ['N+Sg+Nom+PxSg2'],
#  'vuodjame': ['N+Sg+Nom+PxDu1', 'N+Sg+Gen+PxDu1', 'N+Sg+Acc+PxDu1'],
#  'vuodjade': ['N+Sg+Nom+PxDu2'],
#  'vuodjamet': ['N+Sg+Nom+PxPl1', 'N+Sg+Gen+PxPl1', 'N+Sg+Acc+PxPl1'],
#  'vuodjadet': ['N+Sg+Nom+PxPl2'],
#  'vuojade': ['N+Sg+Gen+PxDu2', 'N+Sg+Acc+PxDu2'],
#  'vuojaska': ['N+Sg+Gen+PxDu3', 'N+Sg+Acc+PxDu3'],
#  'vuojadet': ['N+Sg+Gen+PxPl2', 'N+Sg+Acc+PxPl2'],
#  'vuojaset': ['N+Sg+Gen+PxPl3', 'N+Sg+Acc+PxPl3'],
#  'vuodjasan': ['N+Sg+Ill+PxSg1'],
#  'vuodjasat': ['N+Sg+Ill+PxSg2'],
#  'vuodjasis': ['N+Sg+Ill+PxSg3'],
#  'vuodjaseame': ['N+Sg+Ill+PxDu1'],
#  'vuodjaseatte': ['N+Sg+Ill+PxDu2'],
#  'vuodjaseaskka': ['N+Sg+Ill+PxDu3'],
#  'vuodjaseamet': ['N+Sg+Ill+PxPl1'],
#  'vuodjaseattet': ['N+Sg+Ill+PxPl2'],
#  'vuodjaseaset': ['N+Sg+Ill+PxPl3'],
#  'vuojastan': ['N+Sg+Loc+PxSg1'],
#  'vuojastat': ['N+Sg+Loc+PxSg2'],
#  'vuojastis': ['N+Sg+Loc+PxSg3'],
#  'vuojasteame': ['N+Sg+Loc+PxDu1'],
#  'vuojasteatte': ['N+Sg+Loc+PxDu2'],
#  'vuojasteaskka': ['N+Sg+Loc+PxDu3'],
#  'vuojasteamet': ['N+Sg+Loc+PxPl1'],
#  'vuojasteattet': ['N+Sg+Loc+PxPl2'],
#  'vuojasteaset': ['N+Sg+Loc+PxPl3'],
#  'vuojainan': ['N+Sg+Com+PxSg1', 'N+Pl+Loc+PxSg1'],
#  'vuojainat': ['N+Sg+Com+PxSg2', 'N+Pl+Loc+PxSg2'],
#  'vuojainis': ['N+Sg+Com+PxSg3', 'N+Pl+Loc+PxSg3'],
#  'vuojaineame': ['N+Sg+Com+PxDu1', 'N+Pl+Loc+PxDu1'],
#  'vuojaineatte': ['N+Sg+Com+PxDu2', 'N+Pl+Loc+PxDu2'],
#  'vuojaineaskka': ['N+Sg+Com+PxDu3', 'N+Pl+Loc+PxDu3'],
#  'vuojaineamet': ['N+Sg+Com+PxPl1', 'N+Pl+Loc+PxPl1'],
#  'vuojaineattet': ['N+Sg+Com+PxPl2', 'N+Pl+Loc+PxPl2'],
#  'vuojaineaset': ['N+Sg+Com+PxPl3', 'N+Pl+Loc+PxPl3'],
#  'vuojaidan': ['N+Pl+Gen+PxSg1', 'N+Pl+Acc+PxSg1'],
#  'vuojaidat': ['N+Pl+Gen+PxSg2', 'N+Pl+Acc+PxSg2'],
#  'vuojaidis': ['N+Pl+Gen+PxSg3', 'N+Pl+Acc+PxSg3'],
#  'vuojaideame': ['N+Pl+Gen+PxDu1', 'N+Pl+Acc+PxDu1'],
#  'vuojaideatte': ['N+Pl+Gen+PxDu2', 'N+Pl+Acc+PxDu2'],
#  'vuojaideaskka': ['N+Pl+Gen+PxDu3', 'N+Pl+Acc+PxDu3'],
#  'vuojaideamet': ['N+Pl+Gen+PxPl1', 'N+Pl+Acc+PxPl1'],
#  'vuojaideattet': ['N+Pl+Gen+PxPl2', 'N+Pl+Acc+PxPl2'],
#  'vuojaideaset': ['N+Pl+Gen+PxPl3', 'N+Pl+Acc+PxPl3'],
#  'vuojaidasan': ['N+Pl+Ill+PxSg1'],
#  'vuojaidasat': ['N+Pl+Ill+PxSg2'],
#  'vuojaidasas': ['N+Pl+Ill+PxSg3'],
#  'vuojaidasame': ['N+Pl+Ill+PxDu1'],
#  'vuojaidasade': ['N+Pl+Ill+PxDu2'],
#  'vuojaidasaska': ['N+Pl+Ill+PxDu3'],
#  'vuojaidasamet': ['N+Pl+Ill+PxPl1'],
#  'vuojaidasadet': ['N+Pl+Ill+PxPl2'],
#  'vuojaidasaset': ['N+Pl+Ill+PxPl3'],
#  'vuojaidanguin': ['N+Pl+Com+PxSg1'],
#  'vuojaidatguin': ['N+Pl+Com+PxSg2'],
#  'vuojaidisguin': ['N+Pl+Com+PxSg3'],
#  'vuojaideameguin': ['N+Pl+Com+PxDu1'],
#  'vuojaideatteguin': ['N+Pl+Com+PxDu2'],
#  'vuojaideaskkaguin': ['N+Pl+Com+PxDu3'],
#  'vuojaideametguin': ['N+Pl+Com+PxPl1'],
#  'vuojaideattetguin': ['N+Pl+Com+PxPl2'],
#  'vuojaideasetguin': ['N+Pl+Com+PxPl3'],
#  'vuodjanan': ['N+Ess+PxSg1'],
#  'vuodjanat': ['N+Ess+PxSg2'],
#  'vuodjanis': ['N+Ess+PxSg3'],
#  'vuodjaneame': ['N+Ess+PxDu1'],
#  'vuodjaneatte': ['N+Ess+PxDu2'],
#  'vuodjaneaskka': ['N+Ess+PxDu3'],
#  'vuodjaneamet': ['N+Ess+PxPl1'],
#  'vuodjaneattet': ['N+Ess+PxPl2'],
#  'vuodjaneaset': ['N+Ess+PxPl3']}

# %%
være = word_info('leat', pos='V')
være
# Out:
# {'V+Inf': ['leat', 'leahkit'],
#  'V+Ind+Prs+Sg1': ['lean'],
#  'V+Ind+Prs+Sg2': ['leat'],
#  'V+Ind+Prs+Sg3': ['lea'],
#  'V+Ind+Prs+Du1': ['letne', 'ledne'],
#  'V+Ind+Prs+Du2': ['leahppi'],
#  'V+Ind+Prs+Du3': ['leaba'],
#  'V+Ind+Prs+Pl1': ['leat'],
#  'V+Ind+Prs+Pl2': ['lehpet'],
#  'V+Ind+Prs+Pl3': ['leat'],
#  'V+Ind+Prs+ConNeg': ['leat'],
#  'V+Ind+Prt+Sg1': ['ledjen'],
#  'V+Ind+Prt+Sg2': ['ledjet'],
#  'V+Ind+Prt+Sg3': ['lei', 'leai'],
#  'V+Ind+Prt+Du1': ['leimme'],
#  'V+Ind+Prt+Du2': ['leidde'],
#  'V+Ind+Prt+Du3': ['leaigga', 'leigga'],
#  'V+Ind+Prt+Pl1': ['leimmet'],
#  'V+Ind+Prt+Pl2': ['leiddet'],
#  'V+Ind+Prt+Pl3': ['ledje'],
#  'V+Ind+Prt+ConNeg': ['lean'],
#  'V+Cond+Prs+Sg1': ['livččen'],
#  'V+Cond+Prs+Sg2': ['livččet'],
#  'V+Cond+Prs+Sg3': ['livččii'],
#  'V+Cond+Prs+Du1': ['livččiime'],
#  'V+Cond+Prs+Du2': ['livččiide'],
#  'V+Cond+Prs+Du3': ['livččiiga'],
#  'V+Cond+Prs+Pl1': ['livččiimet'],
#  'V+Cond+Prs+Pl2': ['livččiidet'],
#  'V+Cond+Prs+Pl3': ['livčče'],
#  'V+Cond+Prs+ConNeg': ['livčče'],
#  'V+Imprt+Sg1': ['lehkon'],
#  'V+Imprt+Sg2': ['leage'],
#  'V+Imprt+Sg3': ['lehkos'],
#  'V+Imprt+Du1': ['leahkku', 'leadnu'],
#  'V+Imprt+Du2': ['leahkki'],
#  'V+Imprt+Du3': ['lehkoska'],
#  'V+Imprt+Pl1': ['lehkot', 'leatnot'],
#  'V+Imprt+Pl2': ['lehket'],
#  'V+Imprt+Pl3': ['lehkoset'],
#  'V+Imprt+ConNeg': ['leage'],
#  'V+Pot+Prs+Sg1': ['leaččan'],
#  'V+Pot+Prs+Sg2': ['leaččat'],
#  'V+Pot+Prs+Sg3': ['leš', 'leaš', 'leažžá'],
#  'V+Pot+Prs+Du1': ['ležže'],
#  'V+Pot+Prs+Du2': ['leažžabeahtti'],
#  'V+Pot+Prs+Du3': ['leažžaba'],
#  'V+Pot+Prs+Pl1': ['leažžat'],
#  'V+Pot+Prs+Pl2': ['leažžabehtet'],
#  'V+Pot+Prs+Pl3': ['ležžet'],
#  'V+Pot+Prs+ConNeg': ['leš', 'leaš', 'leačča'],
#  'V+Pot+Prt+Sg1': ['ležžen'],
#  'V+Pot+Prt+Sg2': ['ležžet'],
#  'V+Pot+Prt+Sg3': ['leaččai'],
#  'V+Pot+Prt+Du1': ['leaččaime'],
#  'V+Pot+Prt+Du2': ['leaččaide'],
#  'V+Pot+Prt+Du3': ['leaččaiga'],
#  'V+Pot+Prt+Pl1': ['leaččaimet'],
#  'V+Pot+Prt+Pl2': ['leaččaidet'],
#  'V+Pot+Prt+Pl3': ['ležže'],
#  'V+PrfPrc': ['leamaš', 'leamašan'],
#  'V+PrsPrc': ['leahkki'],
#  'V+Actio+Loc': ['leames'],
#  'V+Actio+Ess': ['leamen', 'leame', 'leahkime']}

# %%
være_df = distribution(være.values(), tot_sami)
være_df
# Out:
# med belegg: 61 uten belegg: 4
#                counts
# lea            234100
# leat           178337
# lei             90658
# ledje           34423
# lean            30800
# leai            13381
# ledjen           3890
# leigga           3548
# leamaš           2964
# leaba            2612
# leamen           1985
# livččii          1780
# leage            1583
# leimmet          1513
# lehpet           1441
# letne            1005
# livčče            881
# leahkit           767
# lehkos            753
# leimme            688
# ledjet            632
# leame             490
# leahppi           388
# leamašan          332
# leš               314
# livččen           180
# leaigga           179
# leaš              144
# ležžet             98
# leiddet            94
# ...               ...
# ledne              90
# livččet            89
# lehket             80
# leahkki            52
# livččiimet         46
# leidde             45
# lehkoset           45
# leaččat            41
# leahkku            26
# livččiiga          26
# leaččai            26
# leačča             24
# leahkime           22
# leaččan            16
# leames             14
# ležže              14
# lehkot             13
# livččiime           9
# leadnu              7
# ležžen              6
# leažžaba            5
# lehkoska            5
# lehkon              5
# leažžabehtet        4
# livččiidet          4
# leatnot             3
# livččiide           3
# leažžat             3
# leažžabeahtti       2
# leaččaime           1
#
# [61 rows x 1 columns]

# %%
uni_være = unigram_agg(være_df.head(10).index)

# %%
uni_være.columns = ['leat']

# %%
ja =nb.frame(nb.unigram('ja'), 'ja')

# %%
import pandas as pd

# %%
pd.concat([uni_være, ja], axis=1).plot(figsize=(10,5), lw=4)

# %%
pd.concat([nb.frame(nb.unigram('er'), 'være'), nb.frame(nb.unigram('og'), 'og')], axis=1).plot(figsize=(10,5), lw=4)

# %%
nb.unigram('og').plot()

# %%
unigram_agg(fisk_v_df.head(10).index).plot(figsize=(10,5), lw=4, legend=False)

# %%
unigram_agg(fisk_v_df.head(10).index).plot(figsize=(10,5), lw=4)

# %%
unigram_agg(fisk_v_df.head(5).index).plot(figsize=(10,5), lw=4)

# %%
unigram_agg(fisk_v_df.head(5).index)
# Out:
#           0
# 1958    2.0
# 1961    1.0
# 1963    1.0
# 1966    1.0
# 1967    1.0
# 1969    8.0
# 1976   13.0
# 1977    2.0
# 1979    9.0
# 1980    2.0
# 1981   12.0
# 1982   35.0
# 1983   67.0
# 1984   85.0
# 1985    9.0
# 1986   39.0
# 1987   56.0
# 1988   57.0
# 1989   23.0
# 1990   57.0
# 1991   73.0
# 1992   51.0
# 1993   44.0
# 1994   61.0
# 1995   66.0
# 1996   96.0
# 1997  159.0
# 1998  142.0
# 1999   78.0
# 2000  131.0
# ...     ...
# 1983   25.0
# 1984   16.0
# 1985    3.0
# 1986   17.0
# 1987    8.0
# 1988    1.0
# 1990   32.0
# 1991   22.0
# 1992    7.0
# 1993    7.0
# 1994   19.0
# 1995   11.0
# 1996   32.0
# 1997   23.0
# 1998   38.0
# 1999   18.0
# 2000   48.0
# 2001   53.0
# 2002   28.0
# 2003   98.0
# 2004   35.0
# 2005   16.0
# 2006   16.0
# 2007   24.0
# 2008    9.0
# 2009   48.0
# 2010   35.0
# 2011   26.0
# 2012   29.0
# 2013    4.0
#
# [125 rows x 1 columns]

# %%
(nb.unigram('muohtaskohtera', lang='sme', period=(1970, 2020))/nb.unigram('leat', lang='sme', period=(1970,2020))).plot()

# %%
konk = lambda x, ref_urn: nb.urn_concordance(word=x, urns=nb.refine_book_urn(words=x, urns=ref_urn))

# %%
nb.frame(dict(sami_count.most_common(100))).plot()

# %%
sami_count['gillii']
# Out:
# 1211

# %%
len(sami_count.keys())
# Out:
# 1442261

# %%
sami = nb.frame(sami_count)
nb.frame_sort(sami)

# %%
konk('bivdit', urn)

# %%
nb.concordance(word='bivdit', subject='fiske', lang='sma', kind='html')

# %%
nb.book_corpus(lang='sma', limit=3000)

# %%
nb.urn_concordance(word='giella', urns=urn[:100])
